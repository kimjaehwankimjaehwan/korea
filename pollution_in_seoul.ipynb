# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjaehwankimjaehwan/korea/blob/main/pollution_in_seoul.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import plotly.offline as py
import folium
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# There are multiple csv files available. Lets open the measurement summary

# %%
pol_data = pd.read_csv("/content/drive/MyDrive/한국분석/air_pollution_in_seoul/AirPollutionSeoul/Measurement_summary.csv")
pol_data.head()
# Out:
#    Measurement date  Station code  \
# 0  2017-01-01 00:00           101
# 1  2017-01-01 01:00           101
# 2  2017-01-01 02:00           101
# 3  2017-01-01 03:00           101
# 4  2017-01-01 04:00           101
#
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#      SO2    NO2     O3   CO  PM10  PM2.5
# 0  0.004  0.059  0.002  1.2  73.0   57.0
# 1  0.004  0.058  0.002  1.2  71.0   59.0
# 2  0.004  0.056  0.002  1.2  70.0   59.0
# 3  0.004  0.056  0.002  1.2  70.0   58.0
# 4  0.003  0.051  0.002  1.2  69.0   61.0

# %%
pol_data.shape
# Out:
# (647511, 11)

# %% [markdown]
# There are 11 columns and 647511 rows in the dataset

# %%
pol_data.isnull().sum()
# Out:
# Measurement date    0
# Station code        0
# Address             0
# Latitude            0
# Longitude           0
# SO2                 0
# NO2                 0
# O3                  0
# CO                  0
# PM10                0
# PM2.5               0
# dtype: int64

# %% [markdown]
# There are no null values in the data. Lets see the distribution.

# %%
pol_data[['SO2', 'NO2', 'O3', 'CO', 'PM10', 'PM2.5']].describe()
# Out:
#                  SO2            NO2             O3             CO  \
# count  647511.000000  647511.000000  647511.000000  647511.000000
# mean       -0.001795       0.022519       0.017979       0.509197
# std         0.078832       0.115153       0.099308       0.405319
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%         0.003000       0.016000       0.008000       0.300000
# 50%         0.004000       0.025000       0.021000       0.500000
# 75%         0.005000       0.038000       0.034000       0.600000
# max         3.736000      38.445000      33.600000      71.700000
#
#                 PM10          PM2.5
# count  647511.000000  647511.000000
# mean       43.708051      25.411995
# std        71.137342      43.924595
# min        -1.000000      -1.000000
# 25%        22.000000      11.000000
# 50%        35.000000      19.000000
# 75%        53.000000      31.000000
# max      3586.000000    6256.000000

# %% [markdown]
# Here we can see that the minimum value was -1 in some cases. That is not an acceptable value as there is nothing like negative pollution. This could be a measurement error. Lets count the number of occurrances of this.

# %%
print("We have", pol_data['SO2'].loc[(pol_data['SO2']<0)].count(),"negative values for SO2")
print("We have", pol_data['NO2'].loc[(pol_data['NO2']<0)].count(),"negative values for NO2")
print("We have", pol_data['O3'].loc[(pol_data['O3']<0)].count(),"negative values for O3")
print("We have", pol_data['CO'].loc[(pol_data['CO']<0)].count(),"negative values for CO")
print("We have", pol_data['PM10'].loc[(pol_data['PM10']<0)].count(),"negative values for PM10")
print("We have", pol_data['PM2.5'].loc[(pol_data['PM2.5']<0)].count(),"negative values for PM2.5")
# Out:
# We have 3976 negative values for SO2
# We have 3834 negative values for NO2
# We have 4059 negative values for O3
# We have 4036 negative values for CO
# We have 3962 negative values for PM10
# We have 3973 negative values for PM2.5

# %%
data = [go.Scatter(x=pol_data['Measurement date'],
                   y=pol_data['SO2'], name='SO2'),
        go.Scatter(x=pol_data['Measurement date'],
                   y=pol_data['NO2'], name='NO2'),
        go.Scatter(x=pol_data['Measurement date'],
                   y=pol_data['CO'], name='CO'),
        go.Scatter(x=pol_data['Measurement date'],
                   y=pol_data['O3'], name='O3')]

##layout object
layout = go.Layout(title='Gases Levels',
                    yaxis={'title':'Level (ppm)'},
                    xaxis={'title':'Date'})

## Figure object

fig = go.Figure(data=data, layout=layout)

## Plotting
py.iplot(fig)

# %%
data = pol_data[pol_data['SO2']<0]

# %%
data[['SO2','NO2','O3','CO','PM10','PM2.5']].describe()

# %% [markdown]
# It looks like most of this are occurring in same date, as we can see that the count is same and the mean is almost near to -1 in most of the columns. We can use imputation to replace these values with the mean.

# %%
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=-1, strategy='mean')
df_imputed = pd.DataFrame(imp.fit_transform(pol_data[["SO2","NO2","O3","CO","PM10","PM2.5"]]))
df_imputed.columns = pol_data[["SO2","NO2","O3","CO","PM10","PM2.5"]].columns
df_imputed.index = pol_data.index
remain_df = pol_data[pol_data.columns.difference(["SO2","NO2","O3","CO","PM10","PM2.5"])]
df = pd.concat([remain_df, df_imputed], axis=1)
df.head()
# Out:
#                                              Address   Latitude   Longitude  \
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 2  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 3  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 4  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
#
#    Measurement date  Station code    SO2    NO2     O3   CO  PM10  PM2.5
# 0  2017-01-01 00:00           101  0.004  0.059  0.002  1.2  73.0   57.0
# 1  2017-01-01 01:00           101  0.004  0.058  0.002  1.2  71.0   59.0
# 2  2017-01-01 02:00           101  0.004  0.056  0.002  1.2  70.0   59.0
# 3  2017-01-01 03:00           101  0.004  0.056  0.002  1.2  70.0   58.0
# 4  2017-01-01 04:00           101  0.003  0.051  0.002  1.2  69.0   61.0

# %%
#TODO : Implement the time series with folium
last_entry = df.groupby('Station code').max() #here max is used just to get all type of pointers in the maps
# # last_entry.apply(lambda x: x.sample())
last_entry
# Out:
#                                                         Address   Latitude  \
# Station code
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 102           15, Deoksugung-gil, Jung-gu, Seoul, Republic o...  37.564263
# 103           136, Hannam-daero, Yongsan-gu, Seoul, Republic...  37.540033
# 104           215, Jinheung-ro, Eunpyeong-gu, Seoul, Republi...  37.609823
# 105           32, Segeomjeong-ro 4-gil, Seodaemun-gu, Seoul,...  37.593742
# 106           10, Poeun-ro 6-gil, Mapo-gu, Seoul, Republic o...  37.555580
# 107           18, Ttukseom-ro 3-gil, Seongdong-gu, Seoul, Re...  37.541864
# 108           571, Gwangnaru-ro, Gwangjin-gu, Seoul, Republi...  37.547180
# 109           43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul...  37.575743
# 110           369, Yongmasan-ro, Jungnang-gu, Seoul, Republi...  37.584848
# 111           70, Samyang-ro 2-gil, Seongbuk-gu, Seoul, Repu...  37.606719
# 112           49, Samyang-ro 139-gil, Gangbuk-gu, Seoul, Rep...  37.647930
# 113           34, Sirubong-ro 2-gil, Dobong-gu, Seoul, Repub...  37.654192
# 114           17, Sanggye-ro 23-gil, Nowon-gu, Seoul, Republ...  37.658774
# 115           56, Jungang-ro 52-gil, Yangcheon-gu, Seoul, Re...  37.525939
# 116           71, Gangseo-ro 45da-gil, Gangseo-gu, Seoul, Re...  37.544640
# 117           45, Gamasan-ro 27-gil, Guro-gu, Seoul, Republi...  37.498498
# 118           20, Geumha-ro 21-gil, Geumcheon-gu, Seoul, Rep...  37.452357
# 119           11, Yangsan-ro 23-gil, Yeongdeungpo-gu, Seoul,...  37.525007
# 120           6, Sadang-ro 16a-gil, Dongjak-gu, Seoul, Repub...  37.480917
# 121           14, Sillimdong-gil, Gwanak-gu, Seoul, Republic...  37.487355
# 122           16, Sinbanpo-ro 15-gil, Seocho-gu, Seoul, Repu...  37.504547
# 123           426, Hakdong-ro, Gangnam-gu, Seoul, Republic o...  37.517528
# 124           236, Baekjegobun-ro, Songpa-gu, Seoul, Republi...  37.502686
# 125           59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  37.544962
#
#                Longitude  Measurement date    SO2     NO2      O3    CO  \
# Station code
# 101           127.005008  2019-12-31 23:00  0.406   0.109   0.325  40.0
# 102           126.974676  2019-12-31 23:00  0.082   0.248   0.178   8.7
# 103           127.004850  2019-12-31 23:00  0.016   0.106   0.164   1.9
# 104           126.934848  2019-12-31 23:00  0.080   0.121   0.186   8.0
# 105           126.949679  2019-12-31 23:00  0.027   0.092   0.175  10.9
# 106           126.905597  2019-12-31 23:00  0.332   0.097   0.368  31.3
# 107           127.049659  2019-12-31 23:00  0.144   0.113   0.189  15.3
# 108           127.092493  2019-12-31 23:00  0.342   0.135   0.336  37.5
# 109           127.028885  2019-12-31 23:00  0.312   0.121   0.277  30.9
# 110           127.094023  2019-12-31 23:00  0.223   0.087   0.271  22.3
# 111           127.027279  2019-12-31 23:00  0.195   0.104   5.297  19.2
# 112           127.011952  2019-12-31 23:00  0.097   0.108   0.156   4.1
# 113           127.029088  2019-12-31 23:00  0.045   0.096   0.170  71.7
# 114           127.068505  2019-12-31 23:00  0.120   0.116   0.163  12.0
# 115           126.856603  2019-12-31 23:00  0.111   0.116   0.138   4.4
# 116           126.835151  2019-12-31 23:00  0.233   0.111   1.009   2.5
# 117           126.889692  2019-12-31 23:00  3.736  38.445  33.600  26.2
# 118           126.908296  2019-12-31 23:00  0.115   0.110   0.155   4.6
# 119           126.897370  2019-12-31 23:00  0.254   0.310   0.498  25.6
# 120           126.971481  2019-12-31 23:00  0.120   0.103   0.162  12.6
# 121           126.927102  2019-12-31 23:00  0.365   0.117   0.404  36.8
# 122           126.994458  2019-12-31 23:00  0.141   0.104   1.346   4.5
# 123           127.047470  2019-12-31 23:00  0.370   0.122   0.326  30.0
# 124           127.092509  2019-12-31 23:00  0.176   0.114   0.170  17.2
# 125           127.136792  2019-12-31 23:00  0.378   0.113   0.332  36.7
#
#                 PM10   PM2.5
# Station code
# 101            516.0   513.0
# 102            296.0   276.0
# 103            330.0  6256.0
# 104            985.0   985.0
# 105            985.0   985.0
# 106            985.0   985.0
# 107            985.0   985.0
# 108           1661.0   985.0
# 109            329.0   323.0
# 110            693.0   660.0
# 111           3403.0   995.0
# 112            333.0   572.0
# 113            985.0   985.0
# 114            389.0   387.0
# 115            357.0   350.0
# 116           3586.0   175.0
# 117           1985.0   985.0
# 118            695.0   724.0
# 119            985.0   985.0
# 120            594.0   592.0
# 121           2172.0   985.0
# 122           1985.0   985.0
# 123            561.0   679.0
# 124            985.0   985.0
# 125            622.0   610.0

# %% [markdown]
# Now we need to know about the levels of the above chemicals that are good and bad.

# %%
safe_limit = pd.read_csv('/content/drive/MyDrive/한국분석/air_pollution_in_seoul/AirPollutionSeoul/Original Data/Measurement_item_info.csv')
safe_limit
# Out:
#    Item code Item name Unit of measurement  Good(Blue)  Normal(Green)  \
# 0          1       SO2                 ppm        0.02           0.05
# 1          3       NO2                 ppm        0.03           0.06
# 2          5        CO                 ppm        2.00           9.00
# 3          6        O3                 ppm        0.03           0.09
# 4          8      PM10       Mircrogram/m3       30.00          80.00
# 5          9     PM2.5       Mircrogram/m3       15.00          35.00
#
#    Bad(Yellow)  Very bad(Red)
# 0         0.15            1.0
# 1         0.20            2.0
# 2        15.00           50.0
# 3         0.15            0.5
# 4       150.00          600.0
# 5        75.00          500.0

# %% [markdown]
# The get color function return a color based on the level of polution of each chemical

# %%
#https://stackoverflow.com/a/16729808
def get_colors(data, safe_limit, item):
    item_row = safe_limit.loc[safe_limit['Item name'] == item]
    if (data > item_row.iloc[0]['Very bad(Red)']):
        return 'red'
    elif (data > item_row.iloc[0]['Bad(Yellow)']):
        return 'yellow'
    elif (data > item_row.iloc[0]['Normal(Green)']):
        return 'green'
    else:
        return 'blue'

# %% [markdown]
# We are adding additional columns in the last_entry dataframe for representation purpose.

# %%
last_entry['SO2 Color'] = last_entry['SO2'].apply(get_colors, args =(safe_limit, 'SO2' ))
last_entry['NO2 Color'] = last_entry['NO2'].apply(get_colors, args =(safe_limit, 'NO2' ))
last_entry['O3 Color'] = last_entry['O3'].apply(get_colors, args =(safe_limit, 'O3' ))
last_entry['CO Color'] = last_entry['CO'].apply(get_colors, args =(safe_limit, 'CO' ))
last_entry['PM10 Color'] = last_entry['PM10'].apply(get_colors, args =(safe_limit, 'PM10' ))
last_entry['PM2.5 Color'] = last_entry['PM2.5'].apply(get_colors, args =(safe_limit, 'PM2.5' ))
last_entry
# Out:
#                                                         Address   Latitude  \
# Station code
# 101           19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016
# 102           15, Deoksugung-gil, Jung-gu, Seoul, Republic o...  37.564263
# 103           136, Hannam-daero, Yongsan-gu, Seoul, Republic...  37.540033
# 104           215, Jinheung-ro, Eunpyeong-gu, Seoul, Republi...  37.609823
# 105           32, Segeomjeong-ro 4-gil, Seodaemun-gu, Seoul,...  37.593742
# 106           10, Poeun-ro 6-gil, Mapo-gu, Seoul, Republic o...  37.555580
# 107           18, Ttukseom-ro 3-gil, Seongdong-gu, Seoul, Re...  37.541864
# 108           571, Gwangnaru-ro, Gwangjin-gu, Seoul, Republi...  37.547180
# 109           43, Cheonho-daero 13-gil, Dongdaemun-gu, Seoul...  37.575743
# 110           369, Yongmasan-ro, Jungnang-gu, Seoul, Republi...  37.584848
# 111           70, Samyang-ro 2-gil, Seongbuk-gu, Seoul, Repu...  37.606719
# 112           49, Samyang-ro 139-gil, Gangbuk-gu, Seoul, Rep...  37.647930
# 113           34, Sirubong-ro 2-gil, Dobong-gu, Seoul, Repub...  37.654192
# 114           17, Sanggye-ro 23-gil, Nowon-gu, Seoul, Republ...  37.658774
# 115           56, Jungang-ro 52-gil, Yangcheon-gu, Seoul, Re...  37.525939
# 116           71, Gangseo-ro 45da-gil, Gangseo-gu, Seoul, Re...  37.544640
# 117           45, Gamasan-ro 27-gil, Guro-gu, Seoul, Republi...  37.498498
# 118           20, Geumha-ro 21-gil, Geumcheon-gu, Seoul, Rep...  37.452357
# 119           11, Yangsan-ro 23-gil, Yeongdeungpo-gu, Seoul,...  37.525007
# 120           6, Sadang-ro 16a-gil, Dongjak-gu, Seoul, Repub...  37.480917
# 121           14, Sillimdong-gil, Gwanak-gu, Seoul, Republic...  37.487355
# 122           16, Sinbanpo-ro 15-gil, Seocho-gu, Seoul, Repu...  37.504547
# 123           426, Hakdong-ro, Gangnam-gu, Seoul, Republic o...  37.517528
# 124           236, Baekjegobun-ro, Songpa-gu, Seoul, Republi...  37.502686
# 125           59, Gucheonmyeon-ro 42-gil, Gangdong-gu, Seoul...  37.544962
#
#                Longitude  Measurement date    SO2     NO2      O3    CO  \
# Station code
# 101           127.005008  2019-12-31 23:00  0.406   0.109   0.325  40.0
# 102           126.974676  2019-12-31 23:00  0.082   0.248   0.178   8.7
# 103           127.004850  2019-12-31 23:00  0.016   0.106   0.164   1.9
# 104           126.934848  2019-12-31 23:00  0.080   0.121   0.186   8.0
# 105           126.949679  2019-12-31 23:00  0.027   0.092   0.175  10.9
# 106           126.905597  2019-12-31 23:00  0.332   0.097   0.368  31.3
# 107           127.049659  2019-12-31 23:00  0.144   0.113   0.189  15.3
# 108           127.092493  2019-12-31 23:00  0.342   0.135   0.336  37.5
# 109           127.028885  2019-12-31 23:00  0.312   0.121   0.277  30.9
# 110           127.094023  2019-12-31 23:00  0.223   0.087   0.271  22.3
# 111           127.027279  2019-12-31 23:00  0.195   0.104   5.297  19.2
# 112           127.011952  2019-12-31 23:00  0.097   0.108   0.156   4.1
# 113           127.029088  2019-12-31 23:00  0.045   0.096   0.170  71.7
# 114           127.068505  2019-12-31 23:00  0.120   0.116   0.163  12.0
# 115           126.856603  2019-12-31 23:00  0.111   0.116   0.138   4.4
# 116           126.835151  2019-12-31 23:00  0.233   0.111   1.009   2.5
# 117           126.889692  2019-12-31 23:00  3.736  38.445  33.600  26.2
# 118           126.908296  2019-12-31 23:00  0.115   0.110   0.155   4.6
# 119           126.897370  2019-12-31 23:00  0.254   0.310   0.498  25.6
# 120           126.971481  2019-12-31 23:00  0.120   0.103   0.162  12.6
# 121           126.927102  2019-12-31 23:00  0.365   0.117   0.404  36.8
# 122           126.994458  2019-12-31 23:00  0.141   0.104   1.346   4.5
# 123           127.047470  2019-12-31 23:00  0.370   0.122   0.326  30.0
# 124           127.092509  2019-12-31 23:00  0.176   0.114   0.170  17.2
# 125           127.136792  2019-12-31 23:00  0.378   0.113   0.332  36.7
#
#                 PM10   PM2.5 SO2 Color NO2 Color O3 Color CO Color PM10 Color  \
# Station code
# 101            516.0   513.0    yellow     green   yellow   yellow     yellow
# 102            296.0   276.0     green    yellow   yellow     blue     yellow
# 103            330.0  6256.0      blue     green   yellow     blue     yellow
# 104            985.0   985.0     green     green   yellow     blue        red
# 105            985.0   985.0      blue     green   yellow    green        red
# 106            985.0   985.0    yellow     green   yellow   yellow        red
# 107            985.0   985.0     green     green   yellow   yellow        red
# 108           1661.0   985.0    yellow     green   yellow   yellow        red
# 109            329.0   323.0    yellow     green   yellow   yellow     yellow
# 110            693.0   660.0    yellow     green   yellow   yellow        red
# 111           3403.0   995.0    yellow     green      red   yellow        red
# 112            333.0   572.0     green     green   yellow     blue     yellow
# 113            985.0   985.0      blue     green   yellow      red        red
# 114            389.0   387.0     green     green   yellow    green     yellow
# 115            357.0   350.0     green     green    green     blue     yellow
# 116           3586.0   175.0    yellow     green      red     blue        red
# 117           1985.0   985.0       red       red      red   yellow        red
# 118            695.0   724.0     green     green   yellow     blue        red
# 119            985.0   985.0    yellow    yellow   yellow   yellow        red
# 120            594.0   592.0     green     green   yellow    green     yellow
# 121           2172.0   985.0    yellow     green   yellow   yellow        red
# 122           1985.0   985.0     green     green      red     blue        red
# 123            561.0   679.0    yellow     green   yellow   yellow     yellow
# 124            985.0   985.0    yellow     green   yellow   yellow        red
# 125            622.0   610.0    yellow     green   yellow   yellow        red
#
#              PM2.5 Color
# Station code
# 101                  red
# 102               yellow
# 103                  red
# 104                  red
# 105                  red
# 106                  red
# 107                  red
# 108                  red
# 109               yellow
# 110                  red
# 111                  red
# 112                  red
# 113                  red
# 114               yellow
# 115               yellow
# 116               yellow
# 117                  red
# 118                  red
# 119                  red
# 120                  red
# 121                  red
# 122                  red
# 123                  red
# 124                  red
# 125                  red

# %% [markdown]
# Lets plot the map showing the level of SO2

# %% [markdown]
# ## Pollution of SO2

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of SO2")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['SO2 Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00446ae052af5a45368e8110619ae7fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00446ae052af5a45368e8110619ae7fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00446ae052af5a45368e8110619ae7fd = L.map(
#                 &quot;map_00446ae052af5a45368e8110619ae7fd&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of SO2&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5500e38b7604b658dbc2dfc226dec9fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5500e38b7604b658dbc2dfc226dec9fd.addTo(map_00446ae052af5a45368e8110619ae7fd);
#
#
#             var marker_3c8b3df5e7b6a52954a7d8fde18f6e86 = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_00446ae052af5a45368e8110619ae7fd);
#
#
#             var icon_e2c71b3df8d4d3db752b71dc99ce3c89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c8b3df5e7b6a52954a7d8fde18f6e86.setIcon(icon_e2c71b3df8d4d3db752b71dc99ce3c89);
#
#
#         var popup_3aa4771e59f01190c816d3bc08596188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25b7630f2f0654011d06f67e5d0c7f1d = $(`&lt;div id=&quot;html_25b7630f2f0654011d06f67e5d0c7f1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_3aa4771e59f01190c816d3bc08596188.setContent(html_25b7630f2f0654011d06f67e5d0c7f1d);
#
#
#
#         marker_3c8b3df5e7b6a52954a7d8fde18f6e86.bindPopup(popup_3aa4771e59f01190c816d3bc08596188)
#         ;
#
#
#
#
#             var marker_445f4de2e02cbe160b36745cf51fe641 = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_00446ae052af5a45368e8110619ae7fd);
#
#
#             var icon_fe2162eec4aded85f42e5a339af4ef7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_445f4de2e02cbe160b36745cf51fe641.setIcon(icon_fe2162eec4aded85f42e5a339af4ef7e);
#
#
#         var popup_fd6ef548100c21393ea43e9f3f2a0564 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0407b9038097973f5ecb4d722c5e37b7 = $(`&lt;div id=&quot;html_0407b9038097973f5ecb4d722c5e37b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_fd6ef548100c21393ea43e9f3f2a0564.setContent(html_0407b9038097973f5ecb4d722c5e37b7);
#
#
#
#         marker_445f4de2e02cbe160b36745cf51fe641.bindPopup(popup_fd6ef548100c21393ea43e9f3f2a0564)
#         ;
#
#
#
#
#             var marker_5a5cd3fd4ab185183be8bbce2fe647b1 = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_00446ae052af5a45368e8110619ae7fd);
#
#
#             var icon_7274662ca7465b78fa4d3b7b6256d2b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5a5cd3fd4ab185183be8bbce2fe647b1.setIcon(icon_7274662ca7465b78fa4d3b7b6256d2b2);
#
#
#         var popup_8c2571107396a9f868ff67260dedc569 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_082585beaeb5d0cd84c08dd787341109 = $(`&lt;div id=&quot;html_082585beaeb5d0cd84c08dd787341109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_8c2571107396a9f868ff67260dedc569.setContent(html_082585beaeb5d0cd84c08dd787341109);
#
#
#
#         marker_5a5cd3fd4ab185183be8bbce2fe647b1.bindPopup(popup_8c2571107396a9f868ff67260dedc569)
#         ;
#
#
#
#
#             var marker_8c13c9273730dcb121a72ac736ac3fa2 = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_00446ae052af5a45368e8110619ae7fd);
#
#
#             var icon_d8a9b4bbc34d09e3901875a66c8c5ee4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;

# %% [markdown]
# ## Pollution of NO2

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of NO2")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['NO2 Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65d519e0962eebf3c1bef3c3cb421cd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65d519e0962eebf3c1bef3c3cb421cd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65d519e0962eebf3c1bef3c3cb421cd1 = L.map(
#                 &quot;map_65d519e0962eebf3c1bef3c3cb421cd1&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of NO2&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3a5803da45ae558aafa788bc81bb2b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b3a5803da45ae558aafa788bc81bb2b0.addTo(map_65d519e0962eebf3c1bef3c3cb421cd1);
#
#
#             var marker_9dcbdb1313703ae892a673d92d6b5de0 = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_65d519e0962eebf3c1bef3c3cb421cd1);
#
#
#             var icon_2b6a21224d4a35a2e2e1a90e1f85ea89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9dcbdb1313703ae892a673d92d6b5de0.setIcon(icon_2b6a21224d4a35a2e2e1a90e1f85ea89);
#
#
#         var popup_9b31cc56d3f1815aee37d9b856b6228f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68bed7bf52fea5c10728a593f4eee547 = $(`&lt;div id=&quot;html_68bed7bf52fea5c10728a593f4eee547&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_9b31cc56d3f1815aee37d9b856b6228f.setContent(html_68bed7bf52fea5c10728a593f4eee547);
#
#
#
#         marker_9dcbdb1313703ae892a673d92d6b5de0.bindPopup(popup_9b31cc56d3f1815aee37d9b856b6228f)
#         ;
#
#
#
#
#             var marker_4a15ccb95b366b5d3866112d20a3b31d = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_65d519e0962eebf3c1bef3c3cb421cd1);
#
#
#             var icon_0a58887c5d7963697381e6dc28de7201 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a15ccb95b366b5d3866112d20a3b31d.setIcon(icon_0a58887c5d7963697381e6dc28de7201);
#
#
#         var popup_9a0a406b10f4f6fe7956b096c94403f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a57aa1206449bd4ea7f90932e93988f0 = $(`&lt;div id=&quot;html_a57aa1206449bd4ea7f90932e93988f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_9a0a406b10f4f6fe7956b096c94403f8.setContent(html_a57aa1206449bd4ea7f90932e93988f0);
#
#
#
#         marker_4a15ccb95b366b5d3866112d20a3b31d.bindPopup(popup_9a0a406b10f4f6fe7956b096c94403f8)
#         ;
#
#
#
#
#             var marker_b2e3b2b06e4d4f87a6ac965cc82f0f2e = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_65d519e0962eebf3c1bef3c3cb421cd1);
#
#
#             var icon_437bbb7e208ec07d121751428b3ccd06 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b2e3b2b06e4d4f87a6ac965cc82f0f2e.setIcon(icon_437bbb7e208ec07d121751428b3ccd06);
#
#
#         var popup_2cc21f94456fe497f0bbcd4b09bd7ca2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d38d2fccc2b75ae56d7b7b448e377c23 = $(`&lt;div id=&quot;html_d38d2fccc2b75ae56d7b7b448e377c23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_2cc21f94456fe497f0bbcd4b09bd7ca2.setContent(html_d38d2fccc2b75ae56d7b7b448e377c23);
#
#
#
#         marker_b2e3b2b06e4d4f87a6ac965cc82f0f2e.bindPopup(popup_2cc21f94456fe497f0bbcd4b09bd7ca2)
#         ;
#
#
#
#
#             var marker_9eb8406cac0e8ce6f6559792857344fc = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_65d519e0962eebf3c1bef3c3cb421cd1);
#
#
#             var icon_e2be51edd07d8bd98fa2f093a71cb02c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot

# %% [markdown]
# ## Pollution of O3

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of O3")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['O3 Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ef72875da4b11ff49184c18c5b23ea0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ef72875da4b11ff49184c18c5b23ea0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ef72875da4b11ff49184c18c5b23ea0 = L.map(
#                 &quot;map_8ef72875da4b11ff49184c18c5b23ea0&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of O3&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a40e8a349f7aaa028862fe9df29cfcdc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a40e8a349f7aaa028862fe9df29cfcdc.addTo(map_8ef72875da4b11ff49184c18c5b23ea0);
#
#
#             var marker_8e3b531a0cdd8290185bcf50af89a330 = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_8ef72875da4b11ff49184c18c5b23ea0);
#
#
#             var icon_4668c09b3204fb22c6b6c9e431656bc1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8e3b531a0cdd8290185bcf50af89a330.setIcon(icon_4668c09b3204fb22c6b6c9e431656bc1);
#
#
#         var popup_af6a14d2098540b161dff5a438bf24f6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dda7506032e006519c88698bce8d113 = $(`&lt;div id=&quot;html_2dda7506032e006519c88698bce8d113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_af6a14d2098540b161dff5a438bf24f6.setContent(html_2dda7506032e006519c88698bce8d113);
#
#
#
#         marker_8e3b531a0cdd8290185bcf50af89a330.bindPopup(popup_af6a14d2098540b161dff5a438bf24f6)
#         ;
#
#
#
#
#             var marker_6b88f8478346b79f996774f3fa48b528 = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_8ef72875da4b11ff49184c18c5b23ea0);
#
#
#             var icon_9e54af10f2a8261e2234f22d42f7c72e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6b88f8478346b79f996774f3fa48b528.setIcon(icon_9e54af10f2a8261e2234f22d42f7c72e);
#
#
#         var popup_4fd46a8de6c9ed0bd9e8c7fb3ce7b33c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3683214afa81d8b4a5360c1cfe971f44 = $(`&lt;div id=&quot;html_3683214afa81d8b4a5360c1cfe971f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_4fd46a8de6c9ed0bd9e8c7fb3ce7b33c.setContent(html_3683214afa81d8b4a5360c1cfe971f44);
#
#
#
#         marker_6b88f8478346b79f996774f3fa48b528.bindPopup(popup_4fd46a8de6c9ed0bd9e8c7fb3ce7b33c)
#         ;
#
#
#
#
#             var marker_a9c179fde7fb81ecd6641cf8dd9a7d7a = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_8ef72875da4b11ff49184c18c5b23ea0);
#
#
#             var icon_c271c828f66da038f397da7e671815db = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a9c179fde7fb81ecd6641cf8dd9a7d7a.setIcon(icon_c271c828f66da038f397da7e671815db);
#
#
#         var popup_8dd5e9b66d161af98d9c931bcce41d73 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea9135ec44f211fabd0b686391303caa = $(`&lt;div id=&quot;html_ea9135ec44f211fabd0b686391303caa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_8dd5e9b66d161af98d9c931bcce41d73.setContent(html_ea9135ec44f211fabd0b686391303caa);
#
#
#
#         marker_a9c179fde7fb81ecd6641cf8dd9a7d7a.bindPopup(popup_8dd5e9b66d161af98d9c931bcce41d73)
#         ;
#
#
#
#
#             var marker_6071106bf99634d9d6222a6b4bf2b97c = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_8ef72875da4b11ff49184c18c5b23ea0);
#
#
#             var icon_4306c59903b5203ebfa1dcf7b6bc28a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quo

# %% [markdown]
# ## Pollution of CO

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of CO")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['CO Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbe780af7ea30989939404f0025ee071 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbe780af7ea30989939404f0025ee071&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbe780af7ea30989939404f0025ee071 = L.map(
#                 &quot;map_dbe780af7ea30989939404f0025ee071&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of CO&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10fb1a65442d188e9f9b276aedb1e71e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_10fb1a65442d188e9f9b276aedb1e71e.addTo(map_dbe780af7ea30989939404f0025ee071);
#
#
#             var marker_6acfe2fdc74105d03631e380408acf9f = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_dbe780af7ea30989939404f0025ee071);
#
#
#             var icon_2dd32990d2ecbe126e6bfe51630b7867 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6acfe2fdc74105d03631e380408acf9f.setIcon(icon_2dd32990d2ecbe126e6bfe51630b7867);
#
#
#         var popup_50b29339b6aa6ed6259bba2b98bdbcc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da07f1d0307add6eccc8d97e1df5a12b = $(`&lt;div id=&quot;html_da07f1d0307add6eccc8d97e1df5a12b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_50b29339b6aa6ed6259bba2b98bdbcc9.setContent(html_da07f1d0307add6eccc8d97e1df5a12b);
#
#
#
#         marker_6acfe2fdc74105d03631e380408acf9f.bindPopup(popup_50b29339b6aa6ed6259bba2b98bdbcc9)
#         ;
#
#
#
#
#             var marker_d948befaf9abdb312bf2ccf827900913 = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_dbe780af7ea30989939404f0025ee071);
#
#
#             var icon_d4fcf0e80fe1851cc7fc50c357adf1e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d948befaf9abdb312bf2ccf827900913.setIcon(icon_d4fcf0e80fe1851cc7fc50c357adf1e5);
#
#
#         var popup_e9414b21d89342ff42cf0ea546ef676c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e1ac35bb6a04e5fc2b28d9374edbc652 = $(`&lt;div id=&quot;html_e1ac35bb6a04e5fc2b28d9374edbc652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_e9414b21d89342ff42cf0ea546ef676c.setContent(html_e1ac35bb6a04e5fc2b28d9374edbc652);
#
#
#
#         marker_d948befaf9abdb312bf2ccf827900913.bindPopup(popup_e9414b21d89342ff42cf0ea546ef676c)
#         ;
#
#
#
#
#             var marker_6aff667853967d6c15ffad67675cb523 = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_dbe780af7ea30989939404f0025ee071);
#
#
#             var icon_5a614d5db2abcdfaf4608ede92b79e1a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6aff667853967d6c15ffad67675cb523.setIcon(icon_5a614d5db2abcdfaf4608ede92b79e1a);
#
#
#         var popup_c710d0e00de4f3e958585d5d17d972bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e64edbd71a24ffba8e08319c4f8d072b = $(`&lt;div id=&quot;html_e64edbd71a24ffba8e08319c4f8d072b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_c710d0e00de4f3e958585d5d17d972bf.setContent(html_e64edbd71a24ffba8e08319c4f8d072b);
#
#
#
#         marker_6aff667853967d6c15ffad67675cb523.bindPopup(popup_c710d0e00de4f3e958585d5d17d972bf)
#         ;
#
#
#
#
#             var marker_06c145178acdf3dc7a75f34125d23aef = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_dbe780af7ea30989939404f0025ee071);
#
#
#             var icon_1c8049bd4f943f648906c0bf36aae6ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %% [markdown]
# ## Pollution of PM10

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of PM10")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['PM10 Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21b691bb18defdc3b23a45a84460a69a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21b691bb18defdc3b23a45a84460a69a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21b691bb18defdc3b23a45a84460a69a = L.map(
#                 &quot;map_21b691bb18defdc3b23a45a84460a69a&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of PM10&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afbcbb4a1a11fea7010a82801f29cd06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_afbcbb4a1a11fea7010a82801f29cd06.addTo(map_21b691bb18defdc3b23a45a84460a69a);
#
#
#             var marker_7f3e1af06e494f647c5f159f4d6a520d = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_21b691bb18defdc3b23a45a84460a69a);
#
#
#             var icon_623f0bf825ff02188923d023350f506b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f3e1af06e494f647c5f159f4d6a520d.setIcon(icon_623f0bf825ff02188923d023350f506b);
#
#
#         var popup_9a71355470aec731601dc6759026289f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b587303d2b96393fe8b2011212d7390b = $(`&lt;div id=&quot;html_b587303d2b96393fe8b2011212d7390b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_9a71355470aec731601dc6759026289f.setContent(html_b587303d2b96393fe8b2011212d7390b);
#
#
#
#         marker_7f3e1af06e494f647c5f159f4d6a520d.bindPopup(popup_9a71355470aec731601dc6759026289f)
#         ;
#
#
#
#
#             var marker_1a7d8466b5317007df5219a27a306ee2 = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_21b691bb18defdc3b23a45a84460a69a);
#
#
#             var icon_090f427639d30a16d26ca6874ce812a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1a7d8466b5317007df5219a27a306ee2.setIcon(icon_090f427639d30a16d26ca6874ce812a1);
#
#
#         var popup_021357d3aad07cd7889a4255751770e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6850d20c7ca726ca7c728157a90bd38c = $(`&lt;div id=&quot;html_6850d20c7ca726ca7c728157a90bd38c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_021357d3aad07cd7889a4255751770e6.setContent(html_6850d20c7ca726ca7c728157a90bd38c);
#
#
#
#         marker_1a7d8466b5317007df5219a27a306ee2.bindPopup(popup_021357d3aad07cd7889a4255751770e6)
#         ;
#
#
#
#
#             var marker_220c79e521fd099232bc44cd8a423772 = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_21b691bb18defdc3b23a45a84460a69a);
#
#
#             var icon_0975ae461d5fabbc204a7ff5fa2881f7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_220c79e521fd099232bc44cd8a423772.setIcon(icon_0975ae461d5fabbc204a7ff5fa2881f7);
#
#
#         var popup_64ca734fa54f9ea8fa97ccd1ba40118f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1293ae482d5e0e8f9af387ee5ec2e30c = $(`&lt;div id=&quot;html_1293ae482d5e0e8f9af387ee5ec2e30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_64ca734fa54f9ea8fa97ccd1ba40118f.setContent(html_1293ae482d5e0e8f9af387ee5ec2e30c);
#
#
#
#         marker_220c79e521fd099232bc44cd8a423772.bindPopup(popup_64ca734fa54f9ea8fa97ccd1ba40118f)
#         ;
#
#
#
#
#             var marker_90b9aa9299af692fb99e1ee7dcacaac0 = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_21b691bb18defdc3b23a45a84460a69a);
#
#
#             var icon_8d086b9681062d818664749e4fecd011 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&q

# %% [markdown]
# ## Pollution of PM2.5

# %%
# This creates the map object
m = folium.Map(
    location=[37.541, 126.981], # center of where the map initializes
    #tiles='Stamen Toner', # the style used for the map (defaults to OSM)
    zoom_start=11, # the initial zoom level
    title = "Pollution level of PM2.5")
for ind in last_entry.index:
    #print(row[1][0])
    folium.Marker([last_entry['Latitude'][ind], last_entry['Longitude'][ind]], popup=ind, icon=folium.Icon(color=last_entry['PM2.5 Color'][ind], icon='info-sign')).add_to(m)

# Diplay the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b72e6f01711b4b3ef7119fc5e901c8aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b72e6f01711b4b3ef7119fc5e901c8aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b72e6f01711b4b3ef7119fc5e901c8aa = L.map(
#                 &quot;map_b72e6f01711b4b3ef7119fc5e901c8aa&quot;,
#                 {
#                     center: [37.541, 126.981],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Pollution level of PM2.5&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58cb5826a1355b1353ac6abf2936510 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f58cb5826a1355b1353ac6abf2936510.addTo(map_b72e6f01711b4b3ef7119fc5e901c8aa);
#
#
#             var marker_727a1a751ecbd50868f4cc7887431311 = L.marker(
#                 [37.5720164, 127.0050075],
#                 {}
#             ).addTo(map_b72e6f01711b4b3ef7119fc5e901c8aa);
#
#
#             var icon_4dc7ab29df2148489d11866833e4af24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_727a1a751ecbd50868f4cc7887431311.setIcon(icon_4dc7ab29df2148489d11866833e4af24);
#
#
#         var popup_500348ceec5bebd8916e7e4377ec3873 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9967eaf380ce8ebbae116fa18927b563 = $(`&lt;div id=&quot;html_9967eaf380ce8ebbae116fa18927b563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;101&lt;/div&gt;`)[0];
#                 popup_500348ceec5bebd8916e7e4377ec3873.setContent(html_9967eaf380ce8ebbae116fa18927b563);
#
#
#
#         marker_727a1a751ecbd50868f4cc7887431311.bindPopup(popup_500348ceec5bebd8916e7e4377ec3873)
#         ;
#
#
#
#
#             var marker_6604ef7962e0b358d711e9828d4a4de6 = L.marker(
#                 [37.5642629, 126.9746757],
#                 {}
#             ).addTo(map_b72e6f01711b4b3ef7119fc5e901c8aa);
#
#
#             var icon_d46454fac18d287dcc0c501bf26010a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;yellow&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6604ef7962e0b358d711e9828d4a4de6.setIcon(icon_d46454fac18d287dcc0c501bf26010a6);
#
#
#         var popup_586433ab41fbe69f6d3dca3fdaa7734d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_61c238957dd385002ec060db94c137ee = $(`&lt;div id=&quot;html_61c238957dd385002ec060db94c137ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;102&lt;/div&gt;`)[0];
#                 popup_586433ab41fbe69f6d3dca3fdaa7734d.setContent(html_61c238957dd385002ec060db94c137ee);
#
#
#
#         marker_6604ef7962e0b358d711e9828d4a4de6.bindPopup(popup_586433ab41fbe69f6d3dca3fdaa7734d)
#         ;
#
#
#
#
#             var marker_34fc11d6babe6c9e2c31f012ba097fe0 = L.marker(
#                 [37.54003270000001, 127.00485],
#                 {}
#             ).addTo(map_b72e6f01711b4b3ef7119fc5e901c8aa);
#
#
#             var icon_bf70fa1c331ae04bb38f851140fec98c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34fc11d6babe6c9e2c31f012ba097fe0.setIcon(icon_bf70fa1c331ae04bb38f851140fec98c);
#
#
#         var popup_a3dc2998ff61848dbe6100a277bdc265 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d507bfc3820bc74adc2458e5509f109 = $(`&lt;div id=&quot;html_6d507bfc3820bc74adc2458e5509f109&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103&lt;/div&gt;`)[0];
#                 popup_a3dc2998ff61848dbe6100a277bdc265.setContent(html_6d507bfc3820bc74adc2458e5509f109);
#
#
#
#         marker_34fc11d6babe6c9e2c31f012ba097fe0.bindPopup(popup_a3dc2998ff61848dbe6100a277bdc265)
#         ;
#
#
#
#
#             var marker_6be2a3d872ce684c9b31f46733253daa = L.marker(
#                 [37.6098232, 126.9348476],
#                 {}
#             ).addTo(map_b72e6f01711b4b3ef7119fc5e901c8aa);
#
#
#             var icon_dd33cd3d6d31732e93e40bd26c6e38a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;,

# %% [markdown]
# - TODO : Add time slider in folium maps
